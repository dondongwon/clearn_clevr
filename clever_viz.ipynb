# %%
import torch
import os
import sys
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from scipy.integrate import odeint
import PIL.Image
import PIL.ImageDraw
import tqdm
import json
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
    
from model import *
from IPython.display import HTML

model_name = "9kbuffer_statedict_nonorm"
path = "/home/dongwonl/local/clevr_robot_env/{}".format(model_name)
model_state = torch.load(path)

model = ClassifierCRActionResnet()
model.cuda()
model.load_state_dict(model_state)
model.eval()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-2f469133323e> in <module>
#      23 model = ClassifierCRActionResnet()
#      24 model.cuda()
# ---> 25 model.load_state_dict(model_state)
#      26 model.eval()
#      27
#
# ~/anaconda3/envs/clearn-pytorch/lib/python3.8/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#    1049
#    1050         if len(error_msgs) > 0:
# -> 1051             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
#    1052                                self.__class__.__name__, "\n\t".join(error_msgs)))
#    1053         return _IncompatibleKeys(missing_keys, unexpected_keys)
#
# RuntimeError: Error(s) in loading state_dict for ClassifierCRActionResnet:
# 	Missing key(s) in state_dict: "state_enc.conv1.weight", "state_enc.conv1.bias", "state_enc.bn1.weight", "state_enc.bn1.bias", "state_enc.bn1.running_mean", "state_enc.bn1.running_var", "state_enc.conv2.weight", "state_enc.conv2.bias", "state_enc.bn2.weight", "state_enc.bn2.bias", "state_enc.bn2.running_mean", "state_enc.bn2.running_var", "state_enc.conv3.weight", "state_enc.conv3.bias", "state_enc.bn3.weight", "state_enc.bn3.bias", "state_enc.bn3.running_mean", "state_enc.bn3.running_var", "state_enc.fc4.weight", "state_enc.fc4.bias", "fc0.weight", "fc0.bias", "bn0.weight", "bn0.bias", "bn0.running_mean", "bn0.running_var", "gamma1.weight", "gamma1.bias", "gamma2.weight", "gamma2.bias", "gamma3.weight", "gamma3.bias", "beta1.weight", "beta1.bias", "beta2.weight", "beta2.bias", "beta3.weight", "beta3.bias".
# 	Unexpected key(s) in state_dict: "fc5.weight", "fc5.bias", "bn5.weight", "bn5.bias", "bn5.running_mean", "bn5.running_var", "bn5.num_batches_tracked", "state_enc.unit1.conv.weight", "state_enc.unit1.conv.bias", "state_enc.unit1.bn.weight", "state_enc.unit1.bn.bias", "state_enc.unit1.bn.running_mean", "state_enc.unit1.bn.running_var", "state_enc.unit1.bn.num_batches_tracked", "state_enc.unit2.conv.weight", "state_enc.unit2.conv.bias", "state_enc.unit2.bn.weight", "state_enc.unit2.bn.bias", "state_enc.unit2.bn.running_mean", "state_enc.unit2.bn.running_var", "state_enc.unit2.bn.num_batches_tracked", "state_enc.unit3.conv.weight", "state_enc.unit3.conv.bias", "state_enc.unit3.bn.weight", "state_enc.unit3.bn.bias", "state_enc.unit3.bn.running_mean", "state_enc.unit3.bn.running_var", "state_enc.unit3.bn.num_batches_tracked", "state_enc.unit4.conv.weight", "state_enc.unit4.conv.bias", "state_enc.unit4.bn.weight", "state_enc.unit4.bn.bias", "state_enc.unit4.bn.running_mean", "state_enc.unit4.bn.running_var", "state_enc.unit4.bn.num_batches_tracked", "state_enc.unit5.conv.weight", "state_enc.unit5.conv.bias", "state_enc.unit5.bn.weight", "state_enc.unit5.bn.bias", "state_enc.unit5.bn.running_mean", "state_enc.unit5.bn.running_var", "state_enc.unit5.bn.num_batches_tracked", "state_enc.unit6.conv.weight", "state_enc.unit6.conv.bias", "state_enc.unit6.bn.weight", "state_enc.unit6.bn.bias", "state_enc.unit6.bn.running_mean", "state_enc.unit6.bn.running_var", "state_enc.unit6.bn.num_batches_tracked", "state_enc.unit7.conv.weight", "state_enc.unit7.conv.bias", "state_enc.unit7.bn.weight", "state_enc.unit7.bn.bias", "state_enc.unit7.bn.running_mean", "state_enc.unit7.bn.running_var", "state_enc.unit7.bn.num_batches_tracked", "state_enc.unit8.conv.weight", "state_enc.unit8.conv.bias", "state_enc.unit8.bn.weight", "state_enc.unit8.bn.bias", "state_enc.unit8.bn.running_mean", "state_enc.unit8.bn.running_var", "state_enc.unit8.bn.num_batches_tracked", "state_enc.unit9.conv.weight", "state_enc.unit9.conv.bias", "state_enc.unit9.bn.weight", "state_enc.unit9.bn.bias", "state_enc.unit9.bn.running_mean", "state_enc.unit9.bn.running_var", "state_enc.unit9.bn.num_batches_tracked", "state_enc.unit10.conv.weight", "state_enc.unit10.conv.bias", "state_enc.unit10.bn.weight", "state_enc.unit10.bn.bias", "state_enc.unit10.bn.running_mean", "state_enc.unit10.bn.running_var", "state_enc.unit10.bn.num_batches_tracked", "state_enc.unit11.conv.weight", "state_enc.unit11.conv.bias", "state_enc.unit11.bn.weight", "state_enc.unit11.bn.bias", "state_enc.unit11.bn.running_mean", "state_enc.unit11.bn.running_var", "state_enc.unit11.bn.num_batches_tracked", "state_enc.unit12.conv.weight", "state_enc.unit12.conv.bias", "state_enc.unit12.bn.weight", "state_enc.unit12.bn.bias", "state_enc.unit12.bn.running_mean", "state_enc.unit12.bn.running_var", "state_enc.unit12.bn.num_batches_tracked", "state_enc.unit13.conv.weight", "state_enc.unit13.conv.bias", "state_enc.unit13.bn.weight", "state_enc.unit13.bn.bias", "state_enc.unit13.bn.running_mean", "state_enc.unit13.bn.running_var", "state_enc.unit13.bn.num_batches_tracked", "state_enc.unit14.conv.weight", "state_enc.unit14.conv.bias", "state_enc.unit14.bn.weight", "state_enc.unit14.bn.bias", "state_enc.unit14.bn.running_mean", "state_enc.unit14.bn.running_var", "state_enc.unit14.bn.num_batches_tracked", "state_enc.net.0.conv.weight", "state_enc.net.0.conv.bias", "state_enc.net.0.bn.weight", "state_enc.net.0.bn.bias", "state_enc.net.0.bn.running_mean", "state_enc.net.0.bn.running_var", "state_enc.net.0.bn.num_batches_tracked", "state_enc.net.1.conv.weight", "state_enc.net.1.conv.bias", "state_enc.net.1.bn.weight", "state_enc.net.1.bn.bias", "state_enc.net.1.bn.running_mean", "state_enc.net.1.bn.running_var", "state_enc.net.1.bn.num_batches_tracked", "state_enc.net.2.conv.weight", "state_enc.net.2.conv.bias", "state_enc.net.2.bn.weight", "state_enc.net.2.bn.bias", "state_enc.net.2.bn.running_mean", "state_enc.net.2.bn.running_va ...
# 	size mismatch for fc1.weight: copying a param with shape torch.Size([256, 276]) from checkpoint, the shape in current model is torch.Size([128, 512]).
# 	size mismatch for fc1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for bn1.weight: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for bn1.bias: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for bn1.running_mean: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for bn1.running_var: copying a param with shape torch.Size([256]) from checkpoint, the shape in current model is torch.Size([128]).
# 	size mismatch for fc2.weight: copying a param with shape torch.Size([128, 256]) from checkpoint, the shape in current model is torch.Size([64, 128]).
# 	size mismatch for fc2.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for bn2.weight: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for bn2.bias: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for bn2.running_mean: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for bn2.running_var: copying a param with shape torch.Size([128]) from checkpoint, the shape in current model is torch.Size([64]).
# 	size mismatch for fc3.weight: copying a param with shape torch.Size([64, 128]) from checkpoint, the shape in current model is torch.Size([32, 64]).
# 	size mismatch for fc3.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for bn3.weight: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for bn3.bias: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for bn3.running_mean: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for bn3.running_var: copying a param with shape torch.Size([64]) from checkpoint, the shape in current model is torch.Size([32]).
# 	size mismatch for fc4.weight: copying a param with shape torch.Size([32, 64]) from checkpoint, the shape in current model is torch.Size([2, 32]).
# 	size mismatch for fc4.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([2]).
# 	size mismatch for bn4.weight: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([2]).
# 	size mismatch for bn4.bias: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([2]).
# 	size mismatch for bn4.running_mean: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([2]).
# 	size mismatch for bn4.running_var: copying a param with shape torch.Size([32]) from checkpoint, the shape in current model is torch.Size([2]).
